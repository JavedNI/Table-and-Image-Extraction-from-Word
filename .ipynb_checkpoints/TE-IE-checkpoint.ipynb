# %%
# import relevant modules 
from tkinter import *
from PIL import ImageTk, Image
from tkinter import filedialog as fd
from tkinter import messagebox
import os
import pandas as pd
import xlsxwriter
import docx2txt as d2t
from docx.api import Document


def extract_images():

    messagebox.showinfo("Where to save your content","Find a location where you want to save your images")
    folder_location = fd.askdirectory(initialdir='/')
    if folder_location:
        img_ext = d2t.process(file_path, folder_location)
        saved = messagebox.showinfo('File saved', 'Images saved')

        if ('.xlsx') in excel_path: 
            df = pd.read_excel(excel_path)
        else:
            df = pd.read_csv(excel_path)
        
        ID = df['IMAGE ID'].tolist()
        img_path = os.listdir(folder_location)

    for i in range(len(ID)):
        old_img = os.path.join(folder_location, img_path[i]) 
        new_img = os.path.join(folder_location, ID[i] + '.jpg') 
        os.rename(old_img, new_img)
        print(img_path[i], ID[i])
            
    messagebox.showinfo('Images Extracted', 'Images have been extracted')
    root.after(0, root.destroy)


# function to extract tables from a word docx and write them to an .xlsx or .csv file 
def extract_tables_from_docx(file_path,excel_path): 
    
    # file path for the document being read
    document = Document(file_path)  
    data = []
    # iterates through the tables in the word doc by collating both variables together
    for table in document.tables:  
        # column data stored in keys and values, then stores data in a list 
        keys = (cell.text for cell in table.columns[0].cells) 
        values = (cell.text for cell in table.columns[1].cells)
        data.append(dict(zip(keys,values)))    
    # the dataframe is converted into a .csv or .xlsx file                                       
    df1 = pd.DataFrame(data) 
    if ('.xlsx') in excel_path: 
        df1.to_excel(excel_path, engine = 'xlsxwriter', index = False)
    else:
        df1.to_csv(excel_path ,index=False)
    
    
    
# function to find the document path for the extract_tables_from_docx function
def find_document_path(): 
    
    # file_path stores the file location as a global string to be used by the extract_tables_from_docx function
    global file_path
    file_path = fd.askopenfilename(initialdir="/", title='File search', filetypes=(('docx files', '*.docx'), ('all files', '*.*')))
    # checks if file_path conatins a docx file 
    if ('.docx') in file_path: 
        # checks if the user wants to use the selected file path 
        check = messagebox.askyesno('File Path', 'Use this file path? ' + file_path)
        if check == 1:
            # confirms the file path being used, then changes the state of the buttons on the root label 
            path_info = messagebox.showinfo('File path found', 'Using: '+ file_path)
            open_btn['state'] = 'disabled'
            save_btn['state'] = 'normal'
        else:
            return
    else:
        doc_err = messagebox.showerror('Docx error', 'File path does not contain a .docx file')
    
    
    
# function to save a .xlsx or .csv file 
def save_file():
    global excel_path
    # excel_path stores the string used to save the excel file 
    excel_path = fd.asksaveasfilename(defaultextension=".*", initialdir="/", title="Save File", filetypes=(('xlsx files', '*.xlsx'), ('cvs files','.csv'))) #
    # checks to see if a path was selected 
    if excel_path:
        extract_tables_from_docx(file_path, excel_path)
        # confirms the excel file was saved and closes the program 
        saved = messagebox.showinfo('File saved', 'File saved')
        ext_pop = messagebox.askyesno('Image Extraction', 'Do you want to extract images?')
        if ext_pop == 1:
            extract_images()
        else:
            root.after(0, root.destroy)

        
        
# creates and puts buttons on the root label, when the buttons are pressed they call functions 
root = Tk()
root.title('file finder')
root.geometry('152x50+850+400')

open_btn = Button(root, text='open file', command=find_document_path)
save_btn = Button(root, text='save file', state  = DISABLED, command=save_file) 
open_btn.grid(row=0, column=0)
save_btn.grid(row=0, column=1)

root.mainloop()
# Out:
# image1.jpg 23 - 001
# image10.jpeg 23 - 002
# image100.jpg 23 - 003
# image101.jpg 23 - 004
# image102.jpg 23 - 005
# image103.jpeg 23 - 006
# image104.jpeg 23 - 007
# image105.jpg 23 - 008
# image106.jpg 23 - 009
# image107.jpg 23 - 010
# image108.jpg 23 - 011
# image109.jpeg 23 - 012
# image11.jpeg 23 - 013
# image110.jpg 23 - 014
# image111.jpeg 23 - 015
# image112.jpeg 23 - 016
# image113.jpg 23 - 017
# image114.jpg 23 - 018
# image115.jpg 23 - 019
# image116.jpg 23 – 020
# image117.jpg 23 - 021
# image118.jpg 23 – 022
# image119.jpg 23 - 023
# image12.jpg 23 – 024
# image120.jpg 23 – 025
# image121.jpg 23 – 026
# image122.jpg 23 - 027
# image123.jpg 23 - 028
# image124.jpg 23 - 029
# image125.jpg 23 – 030
# image126.jpg 23 - 031
# image127.jpg 23 – 032
# image128.jpg 23 – 033
# image129.jpg 23 – 034
# image13.jpg 23 – 035
# image130.jpg 23 - 036
# image131.jpg 23 – 037
# image132.jpg 23 – 038
# image133.jpg 23 – 039
# image134.jpg 23 – 040
# image135.png 23 – 041
# image136.jpg 23 – 042
# image137.jpg 23 – 043
# image138.jpg 23 - 044
# image14.jpg 23 – 045
# image141.jpg 23 – 046
# image142.jpg 23 – 047
# image143.jpg 23 – 048
# image144.jpg 23 – 049
# image146.jpg 23 – 050
# image147.jpg 23 – 051
# image148.jpg 23 – 052
# image149.jpg 23 – 053
# image15.jpg 23 – 054
# image150.jpg 23 – 055
# image151.jpg 23 – 056
# image152.jpg 23 – 057
# image153.jpg 23 – 058
# image154.jpg 23 – 059
# image155.jpg 23 – 060
# image156.jpg 23 – 061
# image157.jpg 23 – 062
# image158.jpg 23 – 063
# image159.jpg 23 – 064
# image16.jpeg 23 – 065
# image160.jpg 23 – 066
# image161.jpg 23 – 067
# image162.jpg 23 – 068
# image163.jpg 23 – 069
# image164.jpg 23 – 070
# image165.jpg 23 – 071
# image166.jpg 23 – 072
# image167.jpg 23 – 073
# image168.jpg 23 – 074
# image169.jpg 23 – 075
# image17.jpg 23 – 076
# image170.jpg 23 – 077
# image171.jpg 23 – 078
# image172.jpg 23 – 079
# image173.jpg 23 – 080
# image18.jpg 23 – 081
# image19.jpeg 23 – 082
# image2.jpg 23 – 083
# image20.jpeg 23 – 084
# image21.jpeg 23 – 085
# image22.jpg 23 – 086
# image23.jpg 23 – 087
# image24.jpg 23 – 088
# image25.jpeg 23 – 089
# image26.jpeg 23 – 090
# image27.jpeg 23 – 091
# image28.jpeg 23 – 092
# image29.jpeg 23 – 093
# image3.jpg 23 – 094
# image30.jpeg 23 – 095
# image31.jpeg 23 – 096
# image32.jpeg 23 – 097
# image33.jpeg 23 – 098
# image34.jpg 23 – 099
# image35.jpg 23 – 100
# image36.jpg 23 – 101
# image37.jpg 23 – 102
# image38.jpg 23 – 103
# image39.jpg 23 – 104
# image4.jpeg 23 – 106
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ebenson\AppData\Local\Programs\Python\Python39\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\ebenson\AppData\Local\Temp/ipykernel_9964/2762301926.py", line 94, in save_file
#     extract_images()
#   File "C:\Users\ebenson\AppData\Local\Temp/ipykernel_9964/2762301926.py", line 32, in extract_images
#     os.rename(old_img, new_img)
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:/Users/ebenson/Documents/Gui/py code img\\image40.jpg' -> 'C:/Users/ebenson/Documents/Gui/py code img\\23 – 106.jpg'
